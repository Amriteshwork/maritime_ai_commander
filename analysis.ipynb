# %%
import time
import pandas as pd
import polars as pl
import dask.dataframe as dd

t = time.time()
pd.read_csv("/media/amritesh/bytesviewhdd1/ai_stuf/crimson/data/AIS_2020_12_30.csv", engine='pyarrow')
print("Pandas:", time.time()-t)

t = time.time()
pl.read_csv("/media/amritesh/bytesviewhdd1/ai_stuf/crimson/data/AIS_2020_12_30.csv")
print("Polars:", time.time()-t)

t = time.time()
df = dd.read_csv("/media/amritesh/bytesviewhdd1/ai_stuf/crimson/data/AIS_2020_12_30.csv")
df = df.compute()
print("Dask:", time.time()-t)
# Out:
# Pandas: 0.7528235912322998
# Polars: 0.21048283576965332
# Dask: 11.686482667922974

# %%
import polars as pl

df_polar = pl.read_csv("/media/amritesh/bytesviewhdd1/ai_stuf/crimson/data/AIS_2020_12_30.csv")
df_polar.head()
# Out:
# shape: (5, 17)
# ┌───────────┬─────────────────┬──────────┬────────────┬───┬───────┬───────┬───────┬────────────────┐
# │ MMSI      ┆ BaseDateTime    ┆ LAT      ┆ LON        ┆ … ┆ Width ┆ Draft ┆ Cargo ┆ TransceiverCla │
# │ ---       ┆ ---             ┆ ---      ┆ ---        ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ss             │
# │ i64       ┆ str             ┆ f64      ┆ f64        ┆   ┆ i64   ┆ f64   ┆ i64   ┆ ---            │
# │           ┆                 ┆          ┆            ┆   ┆       ┆       ┆       ┆ str            │
# ╞═══════════╪═════════════════╪══════════╪════════════╪═══╪═══════╪═══════╪═══════╪════════════════╡
# │ 367104050 ┆ 2020-12-30T00:0 ┆ 34.37833 ┆ -120.16082 ┆ … ┆ 7     ┆ null  ┆ null  ┆ A              │
# │           ┆ 0:00            ┆          ┆            ┆   ┆       ┆       ┆       ┆                │
# │ 367702780 ┆ 2020-12-30T00:0 ┆ 33.75269 ┆ -118.22173 ┆ … ┆ null  ┆ null  ┆ null  ┆ A              │
# ...

# %%
df_polar.columns
# Out:
# ['MMSI',
#  'BaseDateTime',
#  'LAT',
#  'LON',
#  'SOG',
#  'COG',
#  'Heading',
#  'VesselName',
#  'IMO',
#  'CallSign',
#  'VesselType',
#  'Status',
#  'Length',
#  'Width',
#  'Draft',
#  'Cargo',
#  'TransceiverClass']

# %%
l = df_polar['VesselName'].str.to_lowercase().unique().to_list()
# MSC Flaminia
# Ever Given
if "ever given" in l:
    print("asdf")

# %%
df_filtered = df_polar.filter(pl.col("VesselName") == "TORONADO")
print(df_filtered.shape)
# Out:
# (938, 17)

# %%
df_filtered
# Out:
# shape: (938, 17)
# ┌───────────┬─────────────────┬──────────┬────────────┬───┬───────┬───────┬───────┬────────────────┐
# │ MMSI      ┆ BaseDateTime    ┆ LAT      ┆ LON        ┆ … ┆ Width ┆ Draft ┆ Cargo ┆ TransceiverCla │
# │ ---       ┆ ---             ┆ ---      ┆ ---        ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ss             │
# │ i64       ┆ str             ┆ f64      ┆ f64        ┆   ┆ i64   ┆ f64   ┆ i64   ┆ ---            │
# │           ┆                 ┆          ┆            ┆   ┆       ┆       ┆       ┆ str            │
# ╞═══════════╪═════════════════╪══════════╪════════════╪═══╪═══════╪═══════╪═══════╪════════════════╡
# │ 367169120 ┆ 2020-12-30T00:0 ┆ 33.71371 ┆ -118.24915 ┆ … ┆ 6     ┆ null  ┆ null  ┆ A              │
# │           ┆ 0:00            ┆          ┆            ┆   ┆       ┆       ┆       ┆                │
# │ 367169120 ┆ 2020-12-30T00:0 ┆ 33.71427 ┆ -118.24625 ┆ … ┆ 6     ┆ null  ┆ null  ┆ A              │
# ...

# %%
df_polar['VesselName'].str.contains("INS KOLKATA").count()
# Out:
# 6849030

# %%
df_1 = df_polar.filter(pl.col("VesselName").str.strip_chars() == "INS KOLKATA")
df_1df_1 = df_polar.filter(
    pl.col("VesselName")
    .str.to_uppercase()
    .str.replace_all(r"\s+", " ")
    .str.strip_chars()
    == "INS KOLKATA"
)
df_1df_1
# Out:
# shape: (0, 17)
# ┌──────┬──────────────┬─────┬─────┬───┬───────┬───────┬───────┬──────────────────┐
# │ MMSI ┆ BaseDateTime ┆ LAT ┆ LON ┆ … ┆ Width ┆ Draft ┆ Cargo ┆ TransceiverClass │
# │ ---  ┆ ---          ┆ --- ┆ --- ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ---              │
# │ i64  ┆ str          ┆ f64 ┆ f64 ┆   ┆ i64   ┆ f64   ┆ i64   ┆ str              │
# ╞══════╪══════════════╪═════╪═════╪═══╪═══════╪═══════╪═══════╪══════════════════╡
# └──────┴──────────────┴─────┴─────┴───┴───────┴───────┴───────┴──────────────────┘

# %%
result = df_polar.filter(pl.col("VesselName").str.to_uppercase() == "INS KOLKATA")
result
# Out:
# shape: (0, 17)
# ┌──────┬──────────────┬─────┬─────┬───┬───────┬───────┬───────┬──────────────────┐
# │ MMSI ┆ BaseDateTime ┆ LAT ┆ LON ┆ … ┆ Width ┆ Draft ┆ Cargo ┆ TransceiverClass │
# │ ---  ┆ ---          ┆ --- ┆ --- ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ---              │
# │ i64  ┆ str          ┆ f64 ┆ f64 ┆   ┆ i64   ┆ f64   ┆ i64   ┆ str              │
# ╞══════╪══════════════╪═════╪═════╪═══╪═══════╪═══════╪═══════╪══════════════════╡
# └──────┴──────────────┴─────┴─────┴───┴───────┴───────┴───────┴──────────────────┘
